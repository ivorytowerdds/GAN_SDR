# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import data, and change all the data type into str
data = pd.read_csv("all.csv",dtype = str)

# %%
data.groupby('ACTION')['ACTION'].count()
# Out:
# ACTION
# CANCEL     124583
# CORRECT     74283
# Cancel          1
# NEW        904440
# Name: ACTION, dtype: int64

# %%
data['ACTION'] = data['ACTION'].str.replace("Cancel",'CANCEL')

# %%
data.shape[0]
# Out:
# 1103307

# %%
data['OPTION_LOCK_PERIOD'].isna().sum()
# Out:
# 1100049

# %%
data['OPTION_PREMIUM'].isna().sum()
# Out:
# 981674

# %%
data.groupby('ACTION')['ACTION'].count()
# Out:
# ACTION
# CANCEL     124584
# CORRECT     74283
# NEW        904440
# Name: ACTION, dtype: int64

# %%
size = data.groupby('ACTION')['ACTION'].count().tolist()
labels = ['CANCEL','CORRECT','NEW']
# Out:
# [124584, 74283, 904440]

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'CANCEL','CORRECT','NEW'
sizes = data.groupby('ACTION')['ACTION'].count().tolist()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90 )
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
data.groupby('INDICATION_OF_END_USER_EXCEPTION')['INDICATION_OF_END_USER_EXCEPTION'].count()
# Out:
# INDICATION_OF_END_USER_EXCEPTION
# N    1054176
# Y      23145
# Name: INDICATION_OF_END_USER_EXCEPTION, dtype: int64

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'N','Y'
sizes = data.groupby('INDICATION_OF_END_USER_EXCEPTION')['INDICATION_OF_END_USER_EXCEPTION'].count().tolist()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90 )
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
labels = 'N','Y'
sizes = data.groupby('BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS')['BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS'].count().tolist()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90 )
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
labels = 'N','Y'
sizes = data.groupby('INDICATION_OF_OTHER_PRICE_AFFECTING_TERM')['INDICATION_OF_OTHER_PRICE_AFFECTING_TERM'].count().tolist()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90 )
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
labels = 'ON','OFF'
sizes = data.groupby('EXECUTION_VENUE')['EXECUTION_VENUE'].count().tolist()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90 )
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
124584/data.shape[0]
# Out:
# 0.11291870712322137

# %%
904440/data.shape[0]
# Out:
# 0.819753704091427

# %%
# copy data, keep the original data clean
data1 = data.copy()
data1.shape
# Out:
# (1103307, 44)

# %%
data1.dropna(axis = 'columns', how = 'all', inplace = True)

# %%
data1.shape
# Out:
# (1103307, 34)

# %%
data1.tail(20)
# Out:
#        DISSEMINATION_ID ORIGINAL_DISSEMINATION_ID   ACTION  \
# 300178         82292687                       NaN      NEW
# 300179         82294629                       NaN      NEW
# 300180         82282749                       NaN      NEW
# 300181         82282750                       NaN      NEW
# 300182         82283113                       NaN      NEW
# 300183         82283752                       NaN      NEW
# 300184         82282619                       NaN      NEW
# 300185         82283973                       NaN      NEW
# 300186         82284581                       NaN      NEW
# 300187         82282935                       NaN      NEW
# 300188         82284161                       NaN      NEW
# 300189         82284328                       NaN      NEW
# 300190         82284329                       NaN      NEW
# 300191         82307946                       NaN      NEW
# 300192         82307947                  82307854   CANCEL
# ...

# %%
data1 = data[data['NOTIONAL_CURRENCY_1'] == 'USD']

# %%
data1.shape
# Out:
# (823555, 44)

# %%
data1.groupby('TAXONOMY')['TAXONOMY'].count()
# Out:
# TAXONOMY
# Credit:Exotic:Other                                                               23812
# Credit:Exotic:StructuredCDS:BespokeTranche                                         2535
# Credit:Exotic:StructuredCDS:ContingentCDS                                           106
# Credit:Exotic:StructuredCDS:FirsttoDefaultNthtoDefault                                5
# Credit:Index:ABX:ABXHE                                                            14431
# Credit:Index:CDX:CDXEmergingMarkets                                               74499
# Credit:Index:CDX:CDXEmergingMarketsDiversified                                       88
# Credit:Index:CDX:CDXHY                                                           161458
# Credit:Index:CDX:CDXIG                                                           138654
# Credit:Index:CMBX:CMBX                                                           191409
# ...

# %%
data1 = data1[(data1['TAXONOMY'] == 'Credit:Index:CDX:CDXHY') | (data1['TAXONOMY'] == 'Credit:Index:CDX:CDXIG')]

# %%
data1.shape
# Out:
# (300112, 44)

# %%
data1.groupby('CLEARED')['CLEARED'].count()
# Out:
# CLEARED
# C    244972
# U     40224
# Name: CLEARED, dtype: int64

# %%
data1.groupby('NOTIONAL_CURRENCY_1')['NOTIONAL_CURRENCY_1'].count().tolist()
# Out:
# [1, 61, 285134]

# %%
285134/data1.shape[0]
# Out:
# 0.999782605646643

# %%
labels = 'CAD','EUR','USD'
sizes = data1.groupby('NOTIONAL_CURRENCY_1')['NOTIONAL_CURRENCY_1'].count().tolist()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90 )
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# we can see that the 1103290 DISSEMINATION_ID has "", clean this column to remove ""
for i, string in enumerate(data1['DISSEMINATION_ID']):
    if '"' in string:
        print(i, string)
        data1['DISSEMINATION_ID'][i] = string.replace("\"","")
# Out:
# 543  "84705863"
# 1301  "83935207"
# 2426  "109578012"
# 3290  "81629614"
# 3404  "81173129"
# 4025  "10959043"
# 5249  "26464942"
# 5983  "26192751"
# 6891  "76103091"
# 7358  "28423916"
# 7852  "13872683"
# 7853  "10750756"
# 9432  "76830004"
# 9939  "13566463"
# 9940  "65072773"
# 10714  "60397432"
# 10717  "60074864"
# 10760  "23258890"
# 10761  "65342215"
# 11154  "22585763"
# 11714  "45262252"
# 12742  "65579038"
# 13080  "44983152"
# 13892  "99585692"
# 14550    "37387017"
# 15184  "20595928"
# 16156  "71996788"
# 16168  "37664193"
# 16865     "20358210"
# 16873  "68306699"
# 17181  "48531569"
# 18203  "71224955"
# 18714  "47814615"
# 19185  "20093429"
# 19188  "78679561"
# 19191  "88497037"
# 20279    "94393703"
# 21184  "87472517"
# 21185  "93313026"
# 21776  "24184428"
# 21784  "72185664"
# 22300  "18042424"
# 23160  "16642374"
# 23991  "18315211"
# 24741  "72409018"
# 25176   "34038205"
# 25957   "31012105"
# 26842  "16154323"
# 27386  "15732089"
# 28192  "16119385"
# ...

# %%
data1.tail(20)
# the " " are removed
# Out:
#         DISSEMINATION_ID ORIGINAL_DISSEMINATION_ID  ACTION  \
# 1103287         82310865                  82299812  CANCEL
# 1103288         82310866                       NaN     NEW
# 1103289         82310876                  82310866  CANCEL
# 1103290        108130327                       NaN     NEW
# 1103291        108130328                       NaN     NEW
# 1103292        108130329                       NaN     NEW
# 1103293        108130330                       NaN     NEW
# 1103294        108130331                       NaN     NEW
# 1103295        108130332                       NaN     NEW
# 1103296        108130333                       NaN     NEW
# 1103297        108130334                       NaN     NEW
# 1103298        108130335                       NaN     NEW
# 1103299        108130336                       NaN     NEW
# 1103300        108130337                       NaN     NEW
# 1103301        108130338                       NaN     NEW
# ...

# %%
# filter the cleared data
#data1 = data1[data1['CLEARED'] == 'C']
#data1.shape
# now the number of data reduces from 1103307 to 447467

# %%
# filter only Credit:Index:CDX:CDXIG and Credit:Index:CDX:CDXHY
data1 = data1.loc[(data1['TAXONOMY'] == "Credit:Index:CDX:CDXIG") | (data1['TAXONOMY'] == "Credit:Index:CDX:CDXHY")]
data1.shape
# now the number of data reduces to 300200
# Out:
# (300200, 34)

# %%
data1.reset_index(inplace = True, drop = True)

# %%
# there is an exception in the data, which effective date is 2571
np.where(data1['EFFECTIVE_DATE'] == "2571-10-09")
# Out:
# (array([263507]),)

# %%
data1.iloc[[263592]].T
# Out:
#                                                                         263592
# DISSEMINATION_ID                                                     108460350
# ORIGINAL_DISSEMINATION_ID                                                  NaN
# ACTION                                                                     NEW
# EXECUTION_TIMESTAMP                                        2019-02-07T20:46:25
# CLEARED                                                                      C
# INDICATION_OF_COLLATERALIZATION                                             FC
# INDICATION_OF_END_USER_EXCEPTION                                             N
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM                                     N
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS                           N
# EXECUTION_VENUE                                                             ON
# EFFECTIVE_DATE                                                      2571-10-09
# ...

# %%
# we want to check whether there are other wrong values in effective date
for i, date in enumerate(data1['EFFECTIVE_DATE']):
    if date[:4] > '2019':
        print(i)
# Out:
# 263507

# %%
data1.drop(index = 263507, inplace = True)

# %%
data1.reset_index(inplace = True, drop = True)

# %%
# filter the duration from EFFECTIVE_DATE to END_DATE which is around 5 years. 4.5 years to 5.5 years
data1['EFFECTIVE_DATE'] = pd.to_datetime(data1['EFFECTIVE_DATE'])
data1['END_DATE'] = pd.to_datetime(data1['END_DATE'])
duration = []
is_5years = []
for i in range(data1.shape[0]):
    diff = data1['END_DATE'][i] - data1['EFFECTIVE_DATE'][i]
    # 1980 = 360*5.5, 1620 = 360*4.5
    duration.append(diff.days)
    if diff.days <= 1980 and diff.days >= 1620:
        is_5years.append(True)
    else:
        is_5years.append(False)
data1['DURATION'] = duration
data1['is5years'] = is_5years

# %%
data1 = data1[data1['is5years']]

# %%
data2 = data1.copy()
data2.shape
# the num of data reduces to 285196
# Out:
# (285134, 46)

# %%
# sort the data by EXECUTION_TIMESTAMP
data2.sort_values(by=['EXECUTION_TIMESTAMP'], inplace = True)

# %%
data2.reset_index(inplace = True, drop = True)
data2.head(20)
# Out:
#    DISSEMINATION_ID ORIGINAL_DISSEMINATION_ID   ACTION  EXECUTION_TIMESTAMP  \
# 0          13507509                       NaN      NEW  2010-11-09T17:31:00
# 1          47687809                       NaN      NEW  2011-03-22T14:20:00
# 2          24439460                       NaN      NEW  2011-08-24T22:06:00
# 3          21134459                       NaN      NEW  2011-09-13T20:31:44
# 4          46228284                  46165040   CANCEL  2011-09-20T13:07:00
# 5          46165040                       NaN      NEW  2011-09-20T13:07:00
# 6          46227946                       NaN      NEW  2011-09-20T17:00:58
# 7          46228285                  46165040  CORRECT  2011-09-20T17:00:58
# 8         107608059                       NaN      NEW  2011-09-22T17:28:01
# 9          11651686                       NaN      NEW  2011-10-14T14:46:54
# 10         11651688                       NaN      NEW  2011-10-28T14:37:35
# ...

# %%
# clean the PRICE_NOTATION_TYPE
data2.groupby(['PRICE_NOTATION_TYPE'])['PRICE_NOTATION_TYPE'].count()
# Out:
# PRICE_NOTATION_TYPE
# Amount               81
# BASISPOINTS           1
# Basis Points       8990
# Basis points     125781
# BasisPoints       24144
# Basispoints       13818
# PERCENTAGE          133
# PRICE                 1
# Percentage         7917
# Price            104157
# UpfrontPoints       114
# Name: PRICE_NOTATION_TYPE, dtype: int64

# %%
notation = {'BASISPOINTS': 'BasisPoints', 'Basis Points': 'BasisPoints', 
              'Basis points':'BasisPoints', 'Basispoints':'BasisPoints',
             'PERCENTAGE':'Percentage', 'PRICE':'Price'}
data2 = data2.replace(notation)
data2.groupby(['PRICE_NOTATION_TYPE'])['PRICE_NOTATION_TYPE'].count()
# Out:
# PRICE_NOTATION_TYPE
# Amount               75
# BasisPoints      172705
# Percentage         8023
# Price            104158
# UpfrontPoints       114
# Name: PRICE_NOTATION_TYPE, dtype: int64

# %%
#data2.fillna("", inplace = True)

# %%
# After sorting the timestamp, we find that some orders are canceled then corrected, but some are only canceled.
# One example: canceled then corrected
data2.loc[(data2['DISSEMINATION_ID'] == '46165040') | (data2['ORIGINAL_DISSEMINATION_ID'] == '46165040')
         |(data2['ORIGINAL_DISSEMINATION_ID'] == '46228285')].T
# Out:
#                                                                          4  \
# DISSEMINATION_ID                                                  46228284
# ORIGINAL_DISSEMINATION_ID                                         46165040
# ACTION                                                              CANCEL
# EXECUTION_TIMESTAMP                                    2011-09-20T13:07:00
# CLEARED                                                                  U
# INDICATION_OF_COLLATERALIZATION                                         PC
# INDICATION_OF_END_USER_EXCEPTION                                         N
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM                                 N
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS                       N
# EXECUTION_VENUE                                                        OFF
# EFFECTIVE_DATE                                         2011-09-20 00:00:00
# ...

# %%
data2.loc[(data2['DISSEMINATION_ID'] == '61046457') |
          (data2['ORIGINAL_DISSEMINATION_ID'] == '61046457') | 
          (data2['ORIGINAL_DISSEMINATION_ID'] == '61105343') |
          (data2['ORIGINAL_DISSEMINATION_ID'] == '61143936')].T
# Out:
#                                                                         25  \
# DISSEMINATION_ID                                                  61105343
# ORIGINAL_DISSEMINATION_ID                                         61046457
# ACTION                                                             CORRECT
# EXECUTION_TIMESTAMP                                    2012-03-20T14:05:00
# CLEARED                                                                  C
# INDICATION_OF_COLLATERALIZATION                                         UC
# INDICATION_OF_END_USER_EXCEPTION                                         N
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM                                 N
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS                       N
# EXECUTION_VENUE                                                        OFF
# EFFECTIVE_DATE                                         2012-03-20 00:00:00
# ...

# %%
a = data2['DISSEMINATION_ID'].tolist()
b = data2['ORIGINAL_DISSEMINATION_ID'].tolist()
order = set(a) & set(b)
len(order)
# Out:
# 20012

# %%
# drop the new order whose DISSEMINATION_ID is in the order
data2.drop(data2.loc[(data2['DISSEMINATION_ID'].isin(order)) & (data2['ACTION'] == 'NEW')].index, inplace = True)
data2.shape
# reduce to 266996
# Out:
# (266996, 46)

# %%
# drop the cancel order whose ORIGINAL_DISSEMINATION_ID is in the order
data2.drop(data2.loc[(data2['ORIGINAL_DISSEMINATION_ID'].isin(order)) & (data2['ACTION'] == 'CANCEL')].index, inplace = True)
data2.shape
# reduce to 246978
# Out:
# (246978, 46)

# %%
# drop the correct order whose DISSEMINATION_ID is in the order
data2.drop(data2.loc[(data2['DISSEMINATION_ID'].isin(order)) & (data2['ACTION'] == 'CORRECT')].index, inplace = True)
data2.shape
# reduce to 245104
# Out:
# (245104, 46)

# %%
# check the result
data2.loc[(data2['DISSEMINATION_ID'] == '61046457') |
          (data2['ORIGINAL_DISSEMINATION_ID'] == '61046457') | 
          (data2['ORIGINAL_DISSEMINATION_ID'] == '61105343') |
          (data2['ORIGINAL_DISSEMINATION_ID'] == '61143936')].T
# Out:
#                                                                         28
# DISSEMINATION_ID                                                  61143936
# ORIGINAL_DISSEMINATION_ID                                         61105343
# ACTION                                                             CORRECT
# EXECUTION_TIMESTAMP                                    2012-03-20T14:05:00
# CLEARED                                                                  C
# INDICATION_OF_COLLATERALIZATION                                         FC
# INDICATION_OF_END_USER_EXCEPTION                                         N
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM                                 N
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS                       N
# EXECUTION_VENUE                                                        OFF
# EFFECTIVE_DATE                                         2012-03-20 00:00:00
# ...

# %%
data2.loc[(data2['DISSEMINATION_ID'] == '46165040') | (data2['ORIGINAL_DISSEMINATION_ID'] == '46165040')
         |(data2['ORIGINAL_DISSEMINATION_ID'] == '46228285')].T
# Out:
#                                                                          7
# DISSEMINATION_ID                                                  46228285
# ORIGINAL_DISSEMINATION_ID                                         46165040
# ACTION                                                             CORRECT
# EXECUTION_TIMESTAMP                                    2011-09-20T17:00:58
# CLEARED                                                                  U
# INDICATION_OF_COLLATERALIZATION                                         PC
# INDICATION_OF_END_USER_EXCEPTION                                         N
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM                                 N
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS                       N
# EXECUTION_VENUE                                                        OFF
# EFFECTIVE_DATE                                         2011-09-20 00:00:00
# ...

# %%
data2.groupby('ACTION').count()
# Out:
#          DISSEMINATION_ID  ORIGINAL_DISSEMINATION_ID  EXECUTION_TIMESTAMP  \
# ACTION
# CANCEL              20312                      20312                20312
# CORRECT              9467                       9467                 9467
# NEW                255417                        251               255417
#
#          CLEARED  INDICATION_OF_COLLATERALIZATION  \
# ACTION
# CANCEL     20312                            14156
# CORRECT     9467                             6710
# NEW       255417                            69999
#
#          INDICATION_OF_END_USER_EXCEPTION  \
# ACTION
# CANCEL                              19235
# CORRECT                              9042
# NEW                                248808
#
#          INDICATION_OF_OTHER_PRICE_AFFECTING_TERM  \
# ACTION
# CANCEL                                      20312
# CORRECT                                      9467
# NEW                                        255417
#
# ...

# %%
# we fimd some of the new order has the original id
data2[(data2['ACTION'] == 'NEW') & (data2['ORIGINAL_DISSEMINATION_ID'].isna()== False)]
# Out:
#        DISSEMINATION_ID ORIGINAL_DISSEMINATION_ID ACTION  EXECUTION_TIMESTAMP  \
# 89492          31869167                  31869166    NEW  2015-07-09T21:03:05
# 92142          33232093                  33231676    NEW  2015-08-10T20:00:49
# 96609          35331257                  35330855    NEW  2015-09-23T17:21:12
# 98620          35879090                  35878804    NEW  2015-10-06T12:33:07
# 99278          36065876                  36064491    NEW  2015-10-09T15:40:59
# 100750         36765264                  36764630    NEW  2015-10-26T18:22:06
# 101281         37095751                  37095436    NEW  2015-10-30T20:12:57
# 101444         37240605                  37238610    NEW  2015-11-03T19:07:19
# 102327         37774585                  37773485    NEW  2015-11-13T14:32:33
# 103523         38310392                  38310273    NEW  2015-11-24T21:00:19
# 103852         38646138                  38645444    NEW  2015-12-01T19:48:35
# ...

# %%
# check whether the original id is in our original data
np.where(data['DISSEMINATION_ID'] =='31869166')
# no data found
# Out:
# (array([], dtype=int64),)

# %%
data2.groupby('INDICATION_OF_END_USER_EXCEPTION').count()
# 7093/(231678+7093) = 0.0297
# Out:
#                                   DISSEMINATION_ID  ORIGINAL_DISSEMINATION_ID  \
# INDICATION_OF_END_USER_EXCEPTION
# N                                           231678                       6978
# Y                                             7093                        574
#
#                                   ACTION  EXECUTION_TIMESTAMP  CLEARED  \
# INDICATION_OF_END_USER_EXCEPTION
# N                                 231678               231678   231678
# Y                                   7093                 7093     7093
#
#                                   INDICATION_OF_COLLATERALIZATION  \
# INDICATION_OF_END_USER_EXCEPTION
# N                                                           57803
# Y                                                            2292
#
#                                   INDICATION_OF_OTHER_PRICE_AFFECTING_TERM  \
# INDICATION_OF_END_USER_EXCEPTION
# N                                                                   231678
# ...

# %%
7093/(231678+7093)
# Out:
# 0.02970628761449255

# %%
data2.groupby('INDICATION_OF_OTHER_PRICE_AFFECTING_TERM').count()
# 3637/(3637+241523) = 0.01484
# Out:
#                                           DISSEMINATION_ID  \
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM
# N                                                   241523
# Y                                                     3637
#
#                                           ORIGINAL_DISSEMINATION_ID  ACTION  \
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM
# N                                                              7764  241523
# Y                                                               292    3637
#
#                                           EXECUTION_TIMESTAMP  CLEARED  \
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM
# N                                                      241523   241523
# Y                                                        3637     3637
#
#                                           INDICATION_OF_COLLATERALIZATION  \
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM
# N                                                                   60337
# ...

# %%
3637/(3637+241523)
# Out:
# 0.014835209658998205

# %%
data2.groupby('BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS').count()
# 44054/(44054+201106) = 0.1797
# Out:
#                                                     DISSEMINATION_ID  \
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS
# N                                                             201106
# Y                                                              44054
#
#                                                     ORIGINAL_DISSEMINATION_ID  \
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS
# N                                                                        7203
# Y                                                                         853
#
#                                                     ACTION  \
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS
# N                                                   201106
# Y                                                    44054
#
#                                                     EXECUTION_TIMESTAMP  \
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS
# ...

# %%
44054/(44054+201106)
# Out:
# 0.17969489313101647

# %%
data2.groupby('EXECUTION_VENUE').count()
# 38150/(38150+207002) = 0.1556
# Out:
#                  DISSEMINATION_ID  ORIGINAL_DISSEMINATION_ID  ACTION  \
# EXECUTION_VENUE
# OFF                         38150                       3544   38150
# ON                         207002                       4504  207002
#
#                  EXECUTION_TIMESTAMP  CLEARED  \
# EXECUTION_VENUE
# OFF                            38150    38150
# ON                            207002   207002
#
#                  INDICATION_OF_COLLATERALIZATION  \
# EXECUTION_VENUE
# OFF                                        28959
# ON                                         33856
#
#                  INDICATION_OF_END_USER_EXCEPTION  \
# EXECUTION_VENUE
# OFF                                         33821
# ON                                         204943
#
#                  INDICATION_OF_OTHER_PRICE_AFFECTING_TERM  \
# EXECUTION_VENUE
# OFF                                                 38150
# ON                                                 207002
#
# ...

# %%
38150/(38150+207002)
# Out:
# 0.15561773919853805

# %%
data2.groupby('PRICE_FORMING_CONTINUATION_DATA').count()
# Out:
#                                  DISSEMINATION_ID  ORIGINAL_DISSEMINATION_ID  \
# PRICE_FORMING_CONTINUATION_DATA
# Amendment                                    2315                        212
# Increase                                        2                          0
# Novation                                     4454                       1721
# Partialtermination                           8793                       1251
# Trade                                      269632                      26846
#
#                                  ACTION  EXECUTION_TIMESTAMP  CLEARED  \
# PRICE_FORMING_CONTINUATION_DATA
# Amendment                          2315                 2315     2315
# Increase                              2                    2        2
# Novation                           4454                 4454     4454
# Partialtermination                 8793                 8793     8793
# Trade                            269632               269632   269632
#
# ...

# %%
data2 = data2[data2['PRICE_FORMING_CONTINUATION_DATA'] != 'Increase']
data2.shape
# Out:
# (285194, 36)

# %%
data2.groupby('PRICE_FORMING_CONTINUATION_DATA').count()
# Out:
#                                  DISSEMINATION_ID  ORIGINAL_DISSEMINATION_ID  \
# PRICE_FORMING_CONTINUATION_DATA
# Amendment                                    2315                        212
# Novation                                     4454                       1721
# Partialtermination                           8793                       1251
# Trade                                      269632                      26846
#
#                                  ACTION  EXECUTION_TIMESTAMP  CLEARED  \
# PRICE_FORMING_CONTINUATION_DATA
# Amendment                          2315                 2315     2315
# Novation                           4454                 4454     4454
# Partialtermination                 8793                 8793     8793
# Trade                            269632               269632   269632
#
#                                  INDICATION_OF_COLLATERALIZATION  \
# PRICE_FORMING_CONTINUATION_DATA
# ...

# %%
data2.groupby('SETTLEMENT_CURRENCY').count()
# Out:
#                      DISSEMINATION_ID  ORIGINAL_DISSEMINATION_ID  ACTION  \
# SETTLEMENT_CURRENCY
# EUR                                 2                          0       2
# USD                             80530                         58   80530
#
#                      EXECUTION_TIMESTAMP  CLEARED  \
# SETTLEMENT_CURRENCY
# EUR                                    2        2
# USD                                80530    80530
#
#                      INDICATION_OF_COLLATERALIZATION  \
# SETTLEMENT_CURRENCY
# EUR                                                2
# USD                                              364
#
#                      INDICATION_OF_END_USER_EXCEPTION  \
# SETTLEMENT_CURRENCY
# EUR                                                 2
# USD                                             80530
#
#                      INDICATION_OF_OTHER_PRICE_AFFECTING_TERM  \
# SETTLEMENT_CURRENCY
# EUR                                                         2
# ...

# %%
data2[data2['SETTLEMENT_CURRENCY'] == 'EUR'].T
# Question: underlying asset is European asset
# Out:
#                                                                             50257  \
# DISSEMINATION_ID                                                         15553314
# ORIGINAL_DISSEMINATION_ID                                                     NaN
# ACTION                                                                        NEW
# EXECUTION_TIMESTAMP                                           2014-06-25T12:13:07
# CLEARED                                                                         C
# INDICATION_OF_COLLATERALIZATION                                                UC
# INDICATION_OF_END_USER_EXCEPTION                                                N
# INDICATION_OF_OTHER_PRICE_AFFECTING_TERM                                        N
# BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS                              Y
# EXECUTION_VENUE                                                                ON
# ...

# %%
data2.groupby('PAYMENT_FREQUENCY_1').count()
# Out:
#                      DISSEMINATION_ID  ORIGINAL_DISSEMINATION_ID  ACTION  \
# PAYMENT_FREQUENCY_1
# 3M                             245159                       8056  245159
# 6M                                  1                          0       1
#
#                      EXECUTION_TIMESTAMP  CLEARED  \
# PAYMENT_FREQUENCY_1
# 3M                                245159   245159
# 6M                                     1        1
#
#                      INDICATION_OF_COLLATERALIZATION  \
# PAYMENT_FREQUENCY_1
# 3M                                             62820
# 6M                                                 1
#
#                      INDICATION_OF_END_USER_EXCEPTION  \
# PAYMENT_FREQUENCY_1
# 3M                                             238770
# 6M                                                  1
#
#                      INDICATION_OF_OTHER_PRICE_AFFECTING_TERM  \
# PAYMENT_FREQUENCY_1
# 3M                                                     245159
# ...

# %%
data2.groupby('DAY_COUNT_CONVENTION').count()
# Out:
#                       DISSEMINATION_ID  ORIGINAL_DISSEMINATION_ID  ACTION  \
# DAY_COUNT_CONVENTION
#  1/1                             23416                       1162   23416
#  30/360                            118                          3     118
#  ACT/360                        219177                       6697  219177
#  Act/360                          2449                        194    2449
#
#                       EXECUTION_TIMESTAMP  CLEARED  \
# DAY_COUNT_CONVENTION
#  1/1                                23416    23416
#  30/360                               118      118
#  ACT/360                           219177   219177
#  Act/360                             2449     2449
#
#                       INDICATION_OF_COLLATERALIZATION  \
# DAY_COUNT_CONVENTION
#  1/1                                                5
#  30/360                                           118
#  ACT/360                                        60975
# ...

# %%
data2['DAY_COUNT_CONVENTION'] = data2['DAY_COUNT_CONVENTION'].str.replace(" ","")

# %%
data2 = data2.replace({'Act/360': 'ACT/360'})
data2.groupby('DAY_COUNT_CONVENTION').count()
# Out:
#                       DISSEMINATION_ID  ORIGINAL_DISSEMINATION_ID  ACTION  \
# DAY_COUNT_CONVENTION
# 1/1                              23416                       1162   23416
# 30/360                             118                          3     118
# ACT/360                         221626                       6891  221626
#
#                       EXECUTION_TIMESTAMP  CLEARED  \
# DAY_COUNT_CONVENTION
# 1/1                                 23416    23416
# 30/360                                118      118
# ACT/360                            221626   221626
#
#                       INDICATION_OF_COLLATERALIZATION  \
# DAY_COUNT_CONVENTION
# 1/1                                                 5
# 30/360                                            118
# ACT/360                                         62698
#
#                       INDICATION_OF_END_USER_EXCEPTION  \
# DAY_COUNT_CONVENTION
# 1/1                                              21526
# ...

# %%
data2.groupby('EMBEDED_OPTION')['EMBEDED_OPTION'].count()
# Out:
# EMBEDED_OPTION
# EMBED1    111
# Name: EMBEDED_OPTION, dtype: int64

# %%
data2.groupby('ADDITIONAL_PRICE_NOTATION_TYPE')['ADDITIONAL_PRICE_NOTATION_TYPE'].count()
# Out:
# ADDITIONAL_PRICE_NOTATION_TYPE
# BasisPoints     26
# Price          439
# Name: ADDITIONAL_PRICE_NOTATION_TYPE, dtype: int64

# %%
data2.shape[0]
# Out:
# 245104

# %%
data2.dropna(axis=1, how='all',inplace = True)

# %%
data2.columns
# Out:
# Index(['DISSEMINATION_ID', 'ORIGINAL_DISSEMINATION_ID', 'ACTION',
#        'EXECUTION_TIMESTAMP', 'CLEARED', 'INDICATION_OF_COLLATERALIZATION',
#        'INDICATION_OF_END_USER_EXCEPTION',
#        'INDICATION_OF_OTHER_PRICE_AFFECTING_TERM',
#        'BLOCK_TRADES_AND_LARGE_NOTIONAL_OFF-FACILITY_SWAPS', 'EXECUTION_VENUE',
#        'EFFECTIVE_DATE', 'END_DATE', 'DAY_COUNT_CONVENTION',
#        'SETTLEMENT_CURRENCY', 'ASSET_CLASS', 'TAXONOMY',
#        'PRICE_FORMING_CONTINUATION_DATA', 'UNDERLYING_ASSET_1',
#        'PRICE_NOTATION_TYPE', 'PRICE_NOTATION',
#        'ADDITIONAL_PRICE_NOTATION_TYPE', 'ADDITIONAL_PRICE_NOTATION',
#        'NOTIONAL_CURRENCY_1', 'ROUNDED_NOTIONAL_AMOUNT_1',
#        'PAYMENT_FREQUENCY_1', 'EMBEDED_OPTION', 'DURATION', 'is5years'],
#       dtype='object')

# %%
data2 = data2[['EXECUTION_TIMESTAMP','ACTION','CLEARED','INDICATION_OF_COLLATERALIZATION','TAXONOMY',
        'PRICE_FORMING_CONTINUATION_DATA','PRICE_NOTATION_TYPE','PRICE_NOTATION','ROUNDED_NOTIONAL_AMOUNT_1']]

# %%
data2[(data2['PRICE_NOTATION_TYPE'] == 'BasisPoints') | (data2['PRICE_NOTATION_TYPE'] == 'Percentage')]
# Out:
#          ACTION CLEARED INDICATION_OF_COLLATERALIZATION  \
# 0           NEW       U                              PC
# 1           NEW       U                              UC
# 3           NEW       U                              FC
# 4        CANCEL       U                              PC
# 5           NEW       U                              PC
# 6           NEW       U                              PC
# 7       CORRECT       U                              PC
# 8           NEW       U                              PC
# 9           NEW       U                              FC
# 15          NEW       U                              FC
# 16          NEW       U                              FC
# 17          NEW       U                              FC
# 18          NEW       U                              PC
# 19          NEW       U                              FC
# 20       CANCEL       U                              PC
# 21      CORRECT       U                              PC
# ...

# %%
data2.shape
# Out:
# (245160, 9)

# %%
data2.groupby('PRICE_NOTATION_TYPE')['PRICE_NOTATION_TYPE'].count()
# Out:
# PRICE_NOTATION_TYPE
# Amount               47
# BasisPoints      151938
# Percentage         6746
# Price             86318
# UpfrontPoints        52
# Name: PRICE_NOTATION_TYPE, dtype: int64

# %%
data3 = data2[(data2['PRICE_NOTATION_TYPE'] == 'BasisPoints') | (data2['PRICE_NOTATION_TYPE'] == 'Percentage')]

# %%
data3.shape
# 158684
# Out:
# (158684, 9)

# %%
data3['PRICE_NOTATION'] = data3['PRICE_NOTATION'].str.replace(",","")
# Out:
# /Users/shuang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data3[data3['PRICE_NOTATION'] == '0'].shape
# 508
# Out:
# (508, 9)

# %%
data3 = data3[data3['PRICE_NOTATION'] != '0']
data3.shape
# 158176
# Out:
# (158176, 9)

# %%
data3['PRICE_NOTATION'] = data3['PRICE_NOTATION'].astype('float')
#data3['PRICE_NOTATION'] = data3['PRICE_NOTATION'].round(2)

# %%
data_perc_1 = data3[(data3['PRICE_NOTATION'] >= 100) & (data3['PRICE_NOTATION'] < 1000) 
                        & (data3['PRICE_NOTATION_TYPE'] == 'Percentage')]
data_perc_1['PRICE_NOTATION'] = data_perc_1['PRICE_NOTATION']/100
data_perc_2 = data3[(data3['PRICE_NOTATION'] >= 1000) & (data3['PRICE_NOTATION'] < 100000) 
                        & (data3['PRICE_NOTATION_TYPE'] == 'Percentage')]
data_perc_2['PRICE_NOTATION'] = data_perc_2['PRICE_NOTATION']/10000
# Out:
# /Users/shuang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/shuang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data_perc_3 = data3[(data3['PRICE_NOTATION'] > 0) & (data3['PRICE_NOTATION'] < 100) 
                    & (data3['PRICE_NOTATION_TYPE'] == 'Percentage')]

# %%
data_basispoint = data3[(data3['PRICE_NOTATION_TYPE'] == 'BasisPoints')]
data_basispoint['PRICE_NOTATION'] = data_basispoint['PRICE_NOTATION']/100
data_basispoint.shape
# Out:
# /Users/shuang/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (151482, 9)

# %%
data_basispoint = data_basispoint[(data_basispoint['PRICE_NOTATION'] < 100) &
                                  (data_basispoint['PRICE_NOTATION'] > 0)]
data_basispoint.shape
# Out:
# (151469, 9)

# %%
data4 = pd.concat([data_perc_1, data_perc_2, data_perc_3, data_basispoint])

# %%
data4.reset_index(inplace = True, drop = True)
data4.shape
# 158159
# Out:
# (158159, 9)

# %%
#price_list = []
#for i, price in enumerate(data3['PRICE_NOTATION']):
#    price_list.append(float(price.replace(",","")))  
#price_series = pd.Series(price_list)

# %%
data4['ROUNDED_NOTIONAL_AMOUNT_1'] = data4['ROUNDED_NOTIONAL_AMOUNT_1'].str.replace(",","")
data4['ROUNDED_NOTIONAL_AMOUNT_1'] = data4['ROUNDED_NOTIONAL_AMOUNT_1'].str.replace("+","")

# %%
data4['ROUNDED_NOTIONAL_AMOUNT_1'] = data4['ROUNDED_NOTIONAL_AMOUNT_1'].astype('float')/1000000

# %%
data4['INDICATION_OF_COLLATERALIZATION'].isna().sum()
# Out:
# 127264

# %%
# other columns are all complete
data4['EXECUTION_TIMESTAMP'].isna().sum()
# Out:
# 0

# %%
data4['ROUNDED_NOTIONAL_AMOUNT_1'].isna().sum()
# Out:
# 0

# %%
data4 = data4.dropna()

# %%
data4.reset_index(inplace = True, drop = True)

# %%
data4.shape
# 11936
# Out:
# (11936, 9)

# %%
#data4 = data4.loc[(data4['PRICE_NOTATION_TYPE'] != 'Amount')]

# %%
data4['PRICE_NOTATION'] = data4['PRICE_NOTATION'].round(2)

# %%
data4.sort_values(by=['EXECUTION_TIMESTAMP'], inplace = True)

# %%
data4.reset_index(inplace = True, drop = True)

# %%
data4.head(50)
# Out:
#     EXECUTION_TIMESTAMP   ACTION CLEARED INDICATION_OF_COLLATERALIZATION  \
# 0   2011-03-22T14:20:00      NEW       U                              UC
# 1   2011-09-20T17:00:58      NEW       U                              PC
# 2   2011-09-20T17:00:58  CORRECT       U                              PC
# 3   2011-09-22T17:28:01      NEW       U                              PC
# 4   2012-03-20T09:56:00  CORRECT       C                              UC
# 5   2012-03-20T14:05:00  CORRECT       C                              FC
# 6   2012-03-20T18:04:00      NEW       U                              PC
# 7   2012-03-20T18:33:00      NEW       U                              UC
# 8   2012-03-20T18:42:40      NEW       U                              PC
# 9   2012-09-20T13:02:00      NEW       U                              UC
# 10  2012-09-20T13:50:52  CORRECT       U                              UC
# 11  2012-09-20T13:50:52      NEW       U                              UC
# ...

# %%
data4['PRICE_NOTATION'].hist(bins = 10)

# %%
data4[data4['PRICE_NOTATION'] > 50].hist(bins = 5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a21c3ec50>,
# ...
#       dtype=object)

# %%
data4.drop(['PRICE_NOTATION_TYPE','EXECUTION_TIMESTAMP'],axis = 1, inplace = True)

# %%
data4.to_csv('clean_version2.csv')

# %%
import pandas as pd
data = pd.read_csv("clean.csv")

# %%
data['PRICE_NOTATION'].describe()
# Out:
# count    89472.000000
# mean       105.862710
# std        970.558954
# min       -847.250000
# 25%          0.680000
# 50%         99.320000
# 75%        106.610000
# max      35836.000000
# Name: PRICE_NOTATION, dtype: float64

# %%
price_range = []
for i in data['PRICE_NOTATION']:
    if i <= 0:
        price_range.append(1)
    if i > 0 and i <= 20:
        price_range.append(2)
    if i > 20 and i <= 50:
        price_range.append(3)
    if i > 50 and i <= 80:
        price_range.append(4)
    if i > 80 and i <= 100:
        price_range.append(5)
    if i > 100 and i <= 200:
        price_range.append(6)
    if i > 200 and i <= 400:
        price_range.append(7)
    if i > 400 and i <= 600:
        price_range.append(8)
    if i > 600 and i <= 10000:
        price_range.append(9)
    if i > 10000 and i <= 100000:
        price_range.append(10)
    if i > 100000 and i <= 1000000:
        price_range.append(11)
    if i > 1000000:
        price_range.append(12)

# %%
data['PRICE_RANGE'] = price_range

# %%
data.groupby(['PRICE_RANGE'])['PRICE_NOTATION'].count()
# Out:
# PRICE_RANGE
# 1        21
# 2     43213
# 3        19
# 4       433
# 5      2057
# 6     43186
# 7        31
# 8       163
# 9       105
# 10      244
# Name: PRICE_NOTATION, dtype: int64

# %%
data5.groupby(['PRICE_RANGE'])['PRICE_NOTATION'].mean()

# %%
data5['PRICE_NOTATION'].plot()
plt.show()

# %%
sns.distplot(data5['PRICE_NOTATION'])
